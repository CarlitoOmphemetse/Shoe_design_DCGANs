# %%
#You first need to download the 'google_images_download' package

#!pip install google_images_download

# %%
from google_images_download import google_images_download
#instantiate the class
response = google_images_download.googleimagesdownload()
arguments = {"keywords":"alberto torresi men shoes, Edgars men shoes,lee cooper formal men shoes, ","limit":100,"print_urls":True}
paths = response.download(arguments)
#print complete paths to the downloaded images
print(paths)
# Out:
# Item no.: 1 --> Item name = alberto torresi men shoes
# Evaluating...
# Starting Download...
# Image URL: http://stat.homeshop18.com/homeshop18/images/productImages/54/alberto-torresi-mens-tan-formal-shoes-medium_c0360f7e1466b7d7f778fb0e18f040c8.jpg
# IOError on an image...trying next one... Error: timed out
# Image URL: http://stat.homeshop18.com/homeshop18/images/productImages/77/alberto-torresi-mens-brown-boots-medium_f2ef3f84844c4e3cde3799396eb4f0ac.jpg
# IOError on an image...trying next one... Error: timed out
# Image URL: https://rukminim1.flixcart.com/image/832/832/jm6mjrk0/shoe/g/j/t/62545-44-alberto-torresi-tan-brown-original-imaewk294zg3guhb.jpeg?q=70
# Completed Image ====> 1.62545-44-alberto-torresi-tan-brown-original-imaewk294zg3guhb.jpeg
# Image URL: https://images-na.ssl-images-amazon.com/images/I/716ZFIh5xfL._UX395_.jpg
# Completed Image ====> 2.716ZFIh5xfL._UX395_.jpg
# ...

# %%
from google_images_download import google_images_download
#instantiate the class
response = google_images_download.googleimagesdownload()
arguments = {"keywords":"alberto torresi men shoes, Edgars men shoes,lee cooper formal men shoes, ","limit":100,"print_urls":True}
paths = response.download(arguments)
#print complete paths to the downloaded images
print(paths)

# %%
# !pip install google_images_download

# %%
from google_images_download import google_images_download
#instantiate the class
response = google_images_download.googleimagesdownload()
arguments = {"keywords":"alberto torresi men shoes, Edgars men shoes,lee cooper formal men shoes, ","limit":100,"print_urls":True}
paths = response.download(arguments)
#print complete paths to the downloaded images
print(paths)
